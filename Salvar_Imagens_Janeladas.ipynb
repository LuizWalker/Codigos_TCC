# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizWalker/Codigos_TCC/blob/main/Salvar_Imagens_Janeladas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Acesso ao Drive

# %%
from google.colab import drive #Para importar do drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Instalação e import das bibliotecas

# %%
#Instalação das bibliotecas necessárias

# !pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.11/dist-packages (3.0.1)

# %%
import pydicom
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #Função de Janelamento

# %%
def janelamento(imagem, distanciamento_janela, centro_janela):

  imagem_float = imagem.astype(float) #conveter para float evitando problemas de arredondamento

  valor_minimo = centro_janela - (distanciamento_janela/2) #Limite inferior da janela
  valor_maximo = centro_janela + (distanciamento_janela/2) #Limite superior da janela

  imagem_float[imagem_float < valor_minimo] = valor_minimo #Valores abaixo do limite inferior da janela são setados pro valor mínimo
  imagem_float[imagem_float > valor_maximo] = valor_maximo #Valores acima do limite superior da janela são setados pro valor mínimo

  imagem_float = ((imagem_float - valor_minimo) / (valor_maximo - valor_minimo)) * 255 #Mapeia os valores para a faixa de 0 a 255

  return imagem_float.astype(np.uint8)

# %% [markdown]
# ##Valores para o Janelamento

# %%
# Valores empíricos para realçar os ossos

distanciamento_janela_ossos = 2000
centro_janela_ossos = 500

#distanciamento_janela_ossos = 500
#centro_janela_ossos = 1100

# %% [markdown]
# #Algoritmo para realizar o janelamento de todas as subpastas

# %%
root_folder = "/content/drive/MyDrive/Imagens_Fraturas_Janelamento" #Lembrar de modificar

output_folder = "/content/drive/MyDrive/Imagens_DICOM_janeladas_e_processadas" #Lembrar de modificar


# 1. Cria a pasta de saída principal se ela não existir
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Pasta de destino '{output_folder}' criada.")

print("Iniciando janelamento e salvamento...")

# 2. Itera sobre as pastas de pacientes dentro da pasta raiz
for patient_folder in os.listdir(root_folder):
    patient_folder_path = os.path.join(root_folder, patient_folder)

    # Ignora arquivos que não são pastas (ex: o próprio DICOM)
    if not os.path.isdir(patient_folder_path):
        continue

    # 3. Cria uma pasta de saída para este paciente
    output_patient_folder = os.path.join(output_folder, patient_folder)
    if not os.path.exists(output_patient_folder):
        os.makedirs(output_patient_folder)

    print(f"Processando paciente: {patient_folder}")

    # 4. Itera sobre os arquivos DICOM dentro da pasta do paciente
    for filename in os.listdir(patient_folder_path):
        if filename.endswith('.dcm'):
            file_path = os.path.join(patient_folder_path, filename)

            try:
                ds = pydicom.dcmread(file_path)
                pixel_data = ds.pixel_array

                janelamento_ossos = janelamento(pixel_data, distanciamento_janela_ossos, centro_janela_ossos)

                # 5. Salva a imagem janelada na pasta do paciente
                output_filename = filename.replace('.dcm', '.png')
                output_path = os.path.join(output_patient_folder, output_filename)

                plt.imsave(output_path, janelamento_ossos, cmap='gray')
                print(f"  - Imagem '{output_filename}' salva com sucesso.")

            except Exception as e:
                print(f"  - Erro ao processar o arquivo '{filename}': {e}")

print("Processamento concluído.")
# Out:
# Iniciando janelamento e salvamento...
# Processando paciente: Paciente_9940_Slices_Fraturados
#   - Imagem '134.png' salva com sucesso.
#   - Imagem '133.png' salva com sucesso.
#   - Imagem '141.png' salva com sucesso.
#   - Imagem '143.png' salva com sucesso.
#   - Imagem '142.png' salva com sucesso.
#   - Imagem '144.png' salva com sucesso.
#   - Imagem '135.png' salva com sucesso.
#   - Imagem '136.png' salva com sucesso.
#   - Imagem '139.png' salva com sucesso.
#   - Imagem '138.png' salva com sucesso.
#   - Imagem '137.png' salva com sucesso.
#   - Imagem '140.png' salva com sucesso.
# Processando paciente: 1.2.826.0.1.3680043.8693
#   - Imagem '19.png' salva com sucesso.
#   - Imagem '11.png' salva com sucesso.
#   - Imagem '14.png' salva com sucesso.
#   - Imagem '2.png' salva com sucesso.
#   - Imagem '15.png' salva com sucesso.
#   - Imagem '17.png' salva com sucesso.
#   - Imagem '10.png' salva com sucesso.
#   - Imagem '18.png' salva com sucesso.
#   - Imagem '16.png' salva com sucesso.
#   - Imagem '12.png' salva com sucesso.
#   - Imagem '1.png' salva com sucesso.
#   - Imagem '13.png' salva com sucesso.
#   - Imagem '26.png' salva com sucesso.
#   - Imagem '32.png' salva com sucesso.
#   - Imagem '22.png' salva com sucesso.
#   - Imagem '21.png' salva com sucesso.
#   - Imagem '33.png' salva com sucesso.
#   - Imagem '27.png' salva com sucesso.
#   - Imagem '20.png' salva com sucesso.
#   - Imagem '25.png' salva com sucesso.
#   - Imagem '24.png' salva com sucesso.
#   - Imagem '31.png' salva com sucesso.
#   - Imagem '3.png' salva com sucesso.
#   - Imagem '29.png' salva com sucesso.
#   - Imagem '28.png' salva com sucesso.
#   - Imagem '30.png' salva com sucesso.
#   - Imagem '23.png' salva com sucesso.
#   - Imagem '39.png' salva com sucesso.
#   - Imagem '42.png' salva com sucesso.
#   - Imagem '51.png' salva com sucesso.
#   - Imagem '38.png' salva com sucesso.
#   - Imagem '46.png' salva com sucesso.
#   - Imagem '43.png' salva com sucesso.
#   - Imagem '36.png' salva com sucesso.
#   - Imagem '48.png' salva com sucesso.
#   - Imagem '49.png' salva com sucesso.
#   - Imagem '50.png' salva com sucesso.
#   - Imagem '4.png' salva com sucesso.
#   - Imagem '47.png' salva com sucesso.
#   - Imagem '35.png' salva com sucesso.
#   - Imagem '5.png' salva com sucesso.
#   - Imagem '41.png' salva com sucesso.
#   - Imagem '34.png' salva com sucesso.
#   - Imagem '52.png' salva com sucesso.
#   - Imagem '45.png' salva com sucesso.
#   - Imagem '37.png' salva com sucesso.
#   - Imagem '44.png' salva com sucesso.
#   - Imagem '40.png' salva com sucesso.
#   - Imagem '61.png' salva com sucesso.
#   - Imagem '56.png' salva com sucesso.
#   - Imagem '67.png' salva com sucesso.
#   - Imagem '6.png' salva com sucesso.
#   - Imagem '63.png' salva com sucesso.
#   - Imagem '54.png' salva com sucesso.
#   - Imagem '65.png' salva com sucesso.
#   - Imagem '55.png' salva com sucesso.
#   - Imagem '66.png' salva com sucesso.
#   - Imagem '62.png' salva com sucesso.
#   - Imagem '68.png' salva com sucesso.
#   - Imagem '60.png' salva com sucesso.
#   - Imagem '8.png' salva com sucesso.
#   - Imagem '58.png' salva com sucesso.
#   - Imagem '9.png' salva com sucesso.
#   - Imagem '64.png' salva com sucesso.
#   - Imagem '7.png' salva com sucesso.
#   - Imagem '69.png' salva com sucesso.
#   - Imagem '59.png' salva com sucesso.
#   - Imagem '53.png' salva com sucesso.
#   - Imagem '57.png' salva com sucesso.
# Processamento concluído.
