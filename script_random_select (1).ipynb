# %%
import os
import shutil
import numpy as np

# %%
pasta_principal = '/media/gpds_p3/HD 1TB/Imagens_saudável_agrupadas'

pasta_separada = '/media/gpds_p3/HD 1TB/Imagens_Janeladas_PNG/Pacientes_Agrupados/Saudaveis_Selecionados_dcm'

# %%
#Selecionar aleotariamente 6854 imagens de 390682

#lista_pasta = os.listdir(pasta_principal)

#lista_pasta_separada = []

# %%
while(1):
    
    random_number = np.random.randint(0,len(lista_pasta)-1)
    lista_pasta_separada.append(lista_pasta[random_number])
    lista_pasta.pop(random_number)
    
    
    if(len(lista_pasta_separada) == 6854):
        print('Código Encerrado')
        break
# Out:
# Código Encerrado

# %%
for i in lista_pasta_separada:
    shutil.move(pasta_principal + '/' + i,pasta_separada + '/' + i) # + '/' para acessar o diretório
